# %% [markdown]
# testing keras custom layer stuff

# %%
# import packages:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import product
import tensorflow as tf
from tensorflow.keras import Input, Model, constraints
from tensorflow.keras.optimizers import Adam
from keras.layers import Layer
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import time

# %% [markdown]
# define classes:

# %%
# need to define a constraint for training the parameters:
class OrderedConstraint(constraints.Constraint):
    # constructor:
    def __init__(self):
        pass

    # call function for constraint:
    def __call__(self, W):
        return tf.sort(W, axis = 2)

# first layer -> membership layer:
class MF_Layer(Layer): 
    # constructor:
    def __init__(self, num_inputs, num_mfs, mf_type, **kwargs):
        super(MF_Layer, self).__init__(**kwargs)
        self.num_inputs = num_inputs
        self.num_mfs = num_mfs

        # check if string passed:
        if not type(mf_type) is str:
            raise TypeError('Only strings are permitted to be passed')
        
        # check if a recognized membership function was passed:
        if any(mf in mf_type for mf in ['Smoothed Triangular', 'Gaussian', 'Generalized Bell']):
            print('Accepted Membership Function passed')
        else:
            raise ValueError('Unrecognized MF passed to function')
        
        # assign mf type to object, which will determine the number of parameters generated:
        if mf_type == 'Gaussian':
            self.mf_type = 'Gaussian'
            self.num_antecedents = 2
            self.constraints = None
            self.init_max = 50.0
            self.init_min = 0.0
        elif mf_type == 'Smoothed Triangular':
            self.mf_type = 'Smoothed Triangular'
            self.num_antecedents = 3
            self.constraints = OrderedConstraint()
            self.init_max = 50.0
            self.init_min = 0.0
        elif mf_type == 'Generalized Bell':
            self.mf_type = 'Generalized Bell'

            self.num_antecedents = 3
            self.constraints = None
            self.init_max = 50.0
            self.init_min = 1.0

        # need to initialize antecedent parameters
        self.mf_params = self.add_weight(
            shape = (self.num_inputs, self.num_mfs, self.num_antecedents),             
            initializer= tf.keras.initializers.RandomUniform(self.init_min, self.init_max),
            trainable = True,
            name = 'Antecedent_Params',
            constraint = self.constraints
        )

    # custom setting of weights:
    def set_weights(self, params):
        # this function is used to set weights based on what a user provides
        # user must provide weights in the form of a np.array of shape (num_mfs, num_params)

        if params.shape != (self.num_inputs, self.num_mfs, self.num_antecedents):
            raise ValueError(f'Parameters provided are not of correct shape, expected ({self.num_inputs}, {self.num_mfs}, {self.num_antecedents})')

        self.mf_params = params

    # plotting the membership functions:
    def plot_membership(self, max_values):
        # make sure that the provided number of max values matches the number of inputs:
        if len(max_values) != self.num_inputs:
            raise ValueError(f'Expected {self.num_inputs} max values, but got {len(max_values)} instead.')
        
        # set names:
        mf_names = [f'MF {i + 1}' for i in range(self.num_mfs)]

        # plot the membership functions:
        # for every input:
        for i in range(self.num_inputs):
            input_mf_params = self.mf_params[i]
            x_values = np.linspace(0, max_values[i], 1000)
            plt.figure(figsize = (12, 8))

            # for every membership function in that input:
            for j in range(self.num_mfs):

                # if gaussian:
                if self.mf_type == 'Gaussian':
                    # define the parameters:
                    mean = input_mf_params[j, 0]  # mean of the gaussian
                    std = input_mf_params[j, 1]   # standard deviation of the gaussian

                    # compute output:
                    y_values = [tf.exp(-0.5 * tf.square((x - mean) / (std + 1e-6))) for x in x_values]

                # if smoothed triangular:
                if self.mf_type == 'Smoothed Triangular':
                    # define parameters
                    a = input_mf_params[j, 0]   # a parameter
                    b = input_mf_params[j, 1]   # b parameter
                    c = input_mf_params[j, 2]   # c parameter

                    # smoothing factor beta:
                    beta = 5

                    # check if we are on the edges:
                    is_left_edge = tf.equal(a, b)
                    is_right_edge = tf.equal(b, c)

                    # compute softplus-based smoothed triangular membership function:
                    left = tf.nn.softplus(beta * (x_values - a)) / (tf.nn.softplus(beta * (b - a)) + 1e-6)
                    right = tf.nn.softplus(beta * (c - x_values)) / (tf.nn.softplus(beta * (c - b)) + 1e-6) 

                    # deal with edge case:
                    left = tf.where((x_values == a) & is_left_edge, 1.0, left)
                    right = tf.where((x_values == c) & is_right_edge, 1.0, right)

                    # compute output:
                    y_values = tf.maximum(0.0, tf.minimum(left, right))

                # if generalized bell:
                if self.mf_type == 'Generalized Bell':
                    # define parameters
                    a = input_mf_params[j, 0]
                    b = input_mf_params[j, 1]
                    c = input_mf_params[j, 2]

                    # clamp b:
                    b = tf.clip_by_value(b, 1e-6, 5.0)

                    # compute output:
                    y_values = [1 / (1 + tf.abs((x - c) / (a + 1e-6)) ** (2 * b)) for x in x_values]

                plt.plot(x_values, y_values, label = f'{mf_names[j]}')
            plt.title(f'Membership Functions for Input X{i + 1}')
            plt.xlabel('Input Value')
            plt.ylabel('Degree of Membership')
            plt.legend()
            plt.grid(True)
        plt.show()

    # function call:
    def call(self, inputs):
        # need to initialize the membership values:
        membership_values = []

        # for every input:
        for i in range(self.num_inputs):
            # get the memberships for that input:
            input_mf_params = self.mf_params[i]

            # need to now compute the fuzzified value for each membership function:
            fuzzified_values = []

            # for every membership function:
            for j in range(self.num_mfs):

                # if gaussian:
                if self.mf_type == 'Gaussian':
                    # define parameters:
                    mean = input_mf_params[j, 0]  # mean of the gaussian
                    std = input_mf_params[j, 1]   # standard deviation of the gaussian

                    # compute output:
                    output = tf.exp(-0.5 * tf.square((inputs[:, i] - mean) / (std + 1e-6)))
                    fuzzified_values.append(output)

                # if smoothed triangular:
                if self.mf_type == 'Smoothed Triangular':
                    # define parameters
                    a = input_mf_params[j, 0]   # a parameter
                    b = input_mf_params[j, 1]   # b parameter
                    c = input_mf_params[j, 2]   # c parameter

                    # smoothing factor beta:
                    beta = 100.0

                    # check if we are on the edges:
                    is_left_edge = tf.equal(a, b)
                    is_right_edge = tf.equal(b, c)

                    # compute softplus-based smoothed triangular membership function:
                    left = tf.nn.softplus(beta * (inputs[:, i] - a)) / (tf.nn.softplus(beta * (b - a)) + 1e-6)
                    right = tf.nn.softplus(beta * (c - inputs[:, i])) / (tf.nn.softplus(beta * (c - b)) + 1e-6)

                    # deal with edge case:
                    left = tf.where((inputs[:, i] == a) & is_left_edge, 1.0, left)
                    right = tf.where((inputs[:, i] == c) & is_right_edge, 1.0, right)

                    # compute output:
                    output = tf.maximum(0.0, tf.minimum(left, right))
                    fuzzified_values.append(output)

                # if generalized bell:
                if self.mf_type == 'Generalized Bell':
                    # define parameters
                    a = input_mf_params[j, 0]
                    b = input_mf_params[j, 1]
                    c = input_mf_params[j, 2]

                    # clamp b:
                    b = tf.clip_by_value(b, 1e-6, 5.0)

                    # compute output:
                    output = 1 / (1 + tf.abs((inputs[:, i] - c) / (a + 1e-6)) ** (2 * b))
                    fuzzified_values.append(output)
            
            # need to now stack the mf values for that given input:
            membership_values.append(tf.stack(fuzzified_values, axis = -1))

        # stack everything and return:
        return tf.stack(membership_values, axis = 1)
    
# second layer -> firing strength layer:
class FS_Layer(Layer):
    # constructor:
    def __init__(self, num_inputs, num_mfs, **kwargs):
        super(FS_Layer, self).__init__(**kwargs)
        self.num_inputs = num_inputs
        self.num_mfs = num_mfs
        self.num_rules = num_mfs ** num_inputs

    # call function:
    def call(self, membership_values):
        # this layer accepts the membership values, which have shape (batch_size, num_inputs, num_mfs):
        batch_size = tf.shape(membership_values)[0]

        # initialize the firing strengths:
        firing_strengths = tf.ones((batch_size, self.num_rules), dtype = tf.float32)

        # generate all the rule combinations:
        rules = list(product(range(self.num_mfs), repeat = self.num_inputs))    # example [(0, 0, 0), (0, 0, 1), ...]

        # need to check each input, each mf combination, and multiply their values together:
        for rule_index, combination in enumerate(rules):
            # print(f'combination: {combination}')
            rule_strength = tf.ones((batch_size, ), dtype = tf.float32)

            # for every input and membership function:
            for input_index, mf_index in enumerate(combination):
                # print(f'input: {input_index + 1} | mf: {mf_index + 1}')

                # correctly extract the fuzzified values based on the combination index:
                rule_strength *= membership_values[:, input_index, mf_index] + 1e-6
            
            # update the firing strengths:
            rule_strength = tf.expand_dims(rule_strength, axis = -1)  # shape: (batch_size, 1)
            firing_strengths = tf.concat(
                [firing_strengths[:, :rule_index], rule_strength, firing_strengths[:, rule_index + 1:]],
                axis = 1,
            )
            # print(f'firing strength: {firing_strengths}')

        return firing_strengths
    
# third layer -> normalization layer:
class NM_Layer(Layer):
    # constructor:
    def __init__(self, num_inputs, num_mfs, **kwargs):
        super(NM_Layer, self).__init__(**kwargs)
        self.num_inputs = num_inputs
        self.num_mfs = num_mfs

    # call function:
    def call(self, firing_strengths):
        # this function accepts inputs of size (batch_size, num_rules).
        # need to first get the total firing strength:
        total_firing_strength = tf.reduce_sum(firing_strengths, axis = 1, keepdims = True)
        
        # can now normalize the firing strengths:
        normalized_strengths = firing_strengths / (total_firing_strength + 1e-10)   # add a buffer in case the total firing strength is zero

        return normalized_strengths
    
# fourth layer -> consequent layer:
class CN_Layer(Layer):
    # constructor: 
    def __init__(self, num_inputs, num_mfs, **kwargs):
        super(CN_Layer, self).__init__(**kwargs)
        self.num_inputs = num_inputs
        self.num_mfs = num_mfs
        self.num_rules = num_mfs ** num_inputs

        # need to initialize the consequent parameters:
        self.consequent_params = self.add_weight(
            shape = (self.num_rules, self.num_inputs + 1),
            initializer = tf.keras.initializers.RandomUniform(-1.0, 1.0, seed = 1234),
            trainable = True,
            name = 'Consequent_Params'
        )

    # this function is used for manually setting the consequent parameters:
    def set_cons(self, params):
        # this function accepts parameters as an array of size (num_rules, num_inputs + 1):
        if params.shape != (self.num_rules, self.num_inputs + 1):
            raise ValueError(f'Parameters provided are not of correct shape, expected ({self.num_rules}, {self.num_inputs + 1})')
        
        # assign parameters:
        self.consequent_params = params

    # call function:
    def call(self, input_list):
        # unpack inputs from list:
        normalized_strengths, inputs = input_list

        # get the batch size:
        batch_size = tf.shape(normalized_strengths)[0]

        # the output is given by the multiplication of the inputs with the consequent weights,
        # such as: o_k = w_bar_k * (x_1 * p_k + x_2 * q_k + x_3 * r_k + ... + s_k)
        # can therefore extend the inputs to be (batch_size, num_inputs + bias) for ease of multiplication:
        inputs_with_bias = tf.concat([inputs, tf.ones((batch_size, 1), dtype = tf.float32)], axis = -1)

        # need to now reshape the normalized strengths to be of size (batch_size, num_rules, 1)
        # this effectively flips it into a 'column vector' of sorts, where each individual value is now vertically aligned
        normalized_strengths = tf.reshape(normalized_strengths, (batch_size, self.num_rules, 1))

        # get the consequent parameters, which have shape (num_rules, num_inputs + 1):
        consequent_params = self.consequent_params

        # expand inputs with bias to match the rule axis: (batch_size, num_rules, num_inputs + 1)
        inputs_with_bias_expanded = tf.expand_dims(inputs_with_bias, axis = 1)

        # calculate the consequent for each rule
        consequents = tf.reduce_sum(normalized_strengths * inputs_with_bias_expanded * consequent_params, axis = 2)

        return consequents

# fifth layer -> output layer:
class O_Layer(Layer):
    # constructor:
    def __init__(self, num_inputs, num_mfs, **kwargs):
        super(O_Layer, self).__init__(**kwargs)
        self.num_inputs = num_inputs
        self.num_output = num_mfs

    # call function:
    def call(self, consequents):
        output = tf.reduce_sum(consequents, axis = 1, keepdims = True)
        return output
    
# define a custom function for building models:
def BuildAnfis(input_shape, num_inputs, num_mfs, mf_type, rate):
    # define the inputs:
    inputs = Input(shape = input_shape)

    # add the custom layers:
    membership_layer = MF_Layer(num_inputs = num_inputs, num_mfs = num_mfs, mf_type = mf_type)(inputs)
    firing_layer = FS_Layer(num_inputs = num_inputs, num_mfs = num_mfs)(membership_layer)
    normalization_layer = NM_Layer(num_inputs = num_inputs, num_mfs = num_mfs)(firing_layer)
    consequent_layer = CN_Layer(num_inputs = num_inputs, num_mfs = num_mfs)([normalization_layer, inputs])
    output_layer = O_Layer(num_inputs = num_inputs, num_mfs = num_mfs)(consequent_layer)

    # create and compile the model:
    model = Model(inputs = inputs, outputs = output_layer)
    model.compile(optimizer = Adam(learning_rate = rate), 
                  loss = 'mse', 
                  metrics = ['mae', tf.keras.metrics.RootMeanSquaredError()])

    return model

# %% [markdown]
# values for debugging the model:

# %%
# these are the testing parameters that I am using for the membership functions:
params = tf.constant(np.array([
    [  # Parameters for input 1
        [0.0, 0.0, 6.0],
        [5/6, 5.0, 55/6],
        [4.0, 10.0, 10.0]
    ],
    [  # Parameters for input 2
        [0.0, 0.0 , 15.0],
        [25/12, 12.5, 275/12],
        [10.0, 25.0, 25.0]
    ],
    [  # Parameters for input 3
        [0.0, 0.0, 30.0],
        [25/6, 25.0, 275/6],
        [15.0, 50.0, 50.0]
    ]
]), dtype = tf.float32)

# these are testing parameters used for debugging:
cons_params = tf.ones(shape = (27, 4), dtype = tf.float32)

# these are testing inputs used for debugging:
input = tf.constant([[8, 5, 32]], dtype = tf.float32)
# input = tf.constant([[8, 5, 32], [2, 17, 22]], dtype = tf.float32)

# %% [markdown]
# need to now import the data:

# %%
# import data from csv as pandas dataframe:
data = pd.read_csv('V3_Data.csv')
print('data loaded successfully')
# Out:
# data loaded successfully

# %% [markdown]
# split into x and y:

# %%
# perform split:
x_data = data.drop(columns = 'Suitability').astype('float32').values
y_data = data['Suitability'].astype('float32').values

# %% [markdown]
# need to now split into training, validation, and testing sets:

# %%
# split the data using train_test_split:
x_train, x_filler, y_train, y_filler = train_test_split(x_data, y_data, test_size = 0.2)
x_val, x_test, y_val, y_test = train_test_split(x_filler, y_filler, test_size = 0.5)

# get the split results:
print(f'training examples have shape: {x_train.shape}')
print(f'validation examples have shape: {x_val.shape}')
print(f'testing examples have shape:{x_test.shape}\n')
# Out:
# training examples have shape: (8000, 3)
# validation examples have shape: (1000, 3)
# testing examples have shape:(1000, 3)

# %% [markdown]
# scale data:

# %%
# define a scaler:
scaler = StandardScaler()

# scale each set:
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# save the scaler:
# dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# make model:

# %%
# make model:
tf.keras.backend.clear_session()
model = BuildAnfis((3,), 3, 3, mf_type = 'Smoothed Triangular', rate = 0.001)
# model.layers[1].set_weights(params = params)
model.layers[1].mf_params.numpy()
# Out:
# Accepted Membership Function passed
# array([[[10.788261 , 18.517536 , 45.725178 ],
#         [10.751284 , 10.591454 , 30.393427 ],
#         [22.058863 ,  8.670277 , 22.525883 ]],
#
#        [[12.70979  , 39.86842  ,  4.559469 ],
#         [17.782372 , 39.814274 , 35.832268 ],
#         [46.197777 , 26.70567  , 27.496492 ]],
#
#        [[20.720821 , 32.62403  , 15.681869 ],
#         [31.82156  , 16.8087   ,  1.195693 ],
#         [ 0.2876997,  8.897305 , 25.085741 ]]], dtype=float32)

# %% [markdown]
# train model:

# %%
# train the damn model:
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)
history = model.fit(x_train, y_train, validation_data = (x_val, y_val), batch_size = 128, epochs = 500, callbacks = early_stopping)
# Out:
# Epoch 1/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 20.6650 - mae: 4.2724 - root_mean_squared_error: 4.5457 - val_loss: 20.3379 - val_mae: 4.2279 - val_root_mean_squared_error: 4.5098
# Epoch 2/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5363 - mae: 4.2482 - root_mean_squared_error: 4.5317 - val_loss: 20.3329 - val_mae: 4.2272 - val_root_mean_squared_error: 4.5092
# Epoch 3/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5916 - mae: 4.2614 - root_mean_squared_error: 4.5378 - val_loss: 20.3263 - val_mae: 4.2264 - val_root_mean_squared_error: 4.5085
# Epoch 4/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.9225 - mae: 4.2911 - root_mean_squared_error: 4.5740 - val_loss: 20.3173 - val_mae: 4.2252 - val_root_mean_squared_error: 4.5075
# Epoch 5/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.7129 - mae: 4.2692 - root_mean_squared_error: 4.5511 - val_loss: 20.3059 - val_mae: 4.2237 - val_root_mean_squared_error: 4.5062
# Epoch 6/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.7653 - mae: 4.2708 - root_mean_squared_error: 4.5568 - val_loss: 20.2919 - val_mae: 4.2219 - val_root_mean_squared_error: 4.5047
# Epoch 7/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4164 - mae: 4.2344 - root_mean_squared_error: 4.5184 - val_loss: 20.2748 - val_mae: 4.2198 - val_root_mean_squared_error: 4.5028
# Epoch 8/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.5809 - mae: 4.2619 - root_mean_squared_error: 4.5365 - val_loss: 20.2550 - val_mae: 4.2173 - val_root_mean_squared_error: 4.5006
# Epoch 9/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5725 - mae: 4.2541 - root_mean_squared_error: 4.5357 - val_loss: 20.2317 - val_mae: 4.2144 - val_root_mean_squared_error: 4.4980
# Epoch 10/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.5324 - mae: 4.2558 - root_mean_squared_error: 4.5313 - val_loss: 20.2056 - val_mae: 4.2112 - val_root_mean_squared_error: 4.4951
# Epoch 11/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3169 - mae: 4.2298 - root_mean_squared_error: 4.5074 - val_loss: 20.1760 - val_mae: 4.2076 - val_root_mean_squared_error: 4.4918
# Epoch 12/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2542 - mae: 4.2216 - root_mean_squared_error: 4.5004 - val_loss: 20.1431 - val_mae: 4.2036 - val_root_mean_squared_error: 4.4881
# Epoch 13/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4825 - mae: 4.2487 - root_mean_squared_error: 4.5256 - val_loss: 20.1069 - val_mae: 4.1993 - val_root_mean_squared_error: 4.4841
# Epoch 14/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3621 - mae: 4.2338 - root_mean_squared_error: 4.5124 - val_loss: 20.0676 - val_mae: 4.1946 - val_root_mean_squared_error: 4.4797
# Epoch 15/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2830 - mae: 4.2227 - root_mean_squared_error: 4.5036 - val_loss: 20.0256 - val_mae: 4.1896 - val_root_mean_squared_error: 4.4750
# Epoch 16/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8423 - mae: 4.1695 - root_mean_squared_error: 4.4543 - val_loss: 19.9803 - val_mae: 4.1842 - val_root_mean_squared_error: 4.4699
# Epoch 17/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.1109 - mae: 4.2012 - root_mean_squared_error: 4.4845 - val_loss: 19.9322 - val_mae: 4.1785 - val_root_mean_squared_error: 4.4645
# Epoch 18/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.0044 - mae: 4.1949 - root_mean_squared_error: 4.4721 - val_loss: 19.8810 - val_mae: 4.1726 - val_root_mean_squared_error: 4.4588
# Epoch 19/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9985 - mae: 4.1871 - root_mean_squared_error: 4.4719 - val_loss: 19.8279 - val_mae: 4.1664 - val_root_mean_squared_error: 4.4529
# Epoch 20/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.0420 - mae: 4.1946 - root_mean_squared_error: 4.4767 - val_loss: 19.7721 - val_mae: 4.1600 - val_root_mean_squared_error: 4.4466
# Epoch 21/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.1272 - mae: 4.2055 - root_mean_squared_error: 4.4863 - val_loss: 19.7144 - val_mae: 4.1533 - val_root_mean_squared_error: 4.4401
# Epoch 22/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.9478 - mae: 4.1853 - root_mean_squared_error: 4.4663 - val_loss: 19.6536 - val_mae: 4.1464 - val_root_mean_squared_error: 4.4332
# Epoch 23/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8934 - mae: 4.1761 - root_mean_squared_error: 4.4601 - val_loss: 19.5909 - val_mae: 4.1392 - val_root_mean_squared_error: 4.4262
# Epoch 24/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7777 - mae: 4.1628 - root_mean_squared_error: 4.4471 - val_loss: 19.5259 - val_mae: 4.1318 - val_root_mean_squared_error: 4.4188
# Epoch 25/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7389 - mae: 4.1567 - root_mean_squared_error: 4.4428 - val_loss: 19.4590 - val_mae: 4.1242 - val_root_mean_squared_error: 4.4112
# Epoch 26/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9049 - mae: 4.1801 - root_mean_squared_error: 4.4614 - val_loss: 19.3905 - val_mae: 4.1165 - val_root_mean_squared_error: 4.4035
# Epoch 27/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.6987 - mae: 4.1577 - root_mean_squared_error: 4.4381 - val_loss: 19.3201 - val_mae: 4.1085 - val_root_mean_squared_error: 4.3955
# Epoch 28/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.6753 - mae: 4.1571 - root_mean_squared_error: 4.4356 - val_loss: 19.2483 - val_mae: 4.1004 - val_root_mean_squared_error: 4.3873
# Epoch 29/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.4858 - mae: 4.1345 - root_mean_squared_error: 4.4142 - val_loss: 19.1747 - val_mae: 4.0921 - val_root_mean_squared_error: 4.3789
# Epoch 30/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.2568 - mae: 4.1072 - root_mean_squared_error: 4.3882 - val_loss: 19.1000 - val_mae: 4.0837 - val_root_mean_squared_error: 4.3704
# Epoch 31/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.1621 - mae: 4.0969 - root_mean_squared_error: 4.3773 - val_loss: 19.0236 - val_mae: 4.0751 - val_root_mean_squared_error: 4.3616
# Epoch 32/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.2429 - mae: 4.1072 - root_mean_squared_error: 4.3867 - val_loss: 18.9461 - val_mae: 4.0664 - val_root_mean_squared_error: 4.3527
# Epoch 33/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.4440 - mae: 4.1258 - root_mean_squared_error: 4.4093 - val_loss: 18.8671 - val_mae: 4.0575 - val_root_mean_squared_error: 4.3436
# Epoch 34/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.2721 - mae: 4.1126 - root_mean_squared_error: 4.3899 - val_loss: 18.7869 - val_mae: 4.0485 - val_root_mean_squared_error: 4.3344
# Epoch 35/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.9500 - mae: 4.0692 - root_mean_squared_error: 4.3530 - val_loss: 18.7062 - val_mae: 4.0394 - val_root_mean_squared_error: 4.3251
# Epoch 36/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7939 - mae: 4.0637 - root_mean_squared_error: 4.3351 - val_loss: 18.6238 - val_mae: 4.0301 - val_root_mean_squared_error: 4.3155
# Epoch 37/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.0646 - mae: 4.0883 - root_mean_squared_error: 4.3662 - val_loss: 18.5397 - val_mae: 4.0207 - val_root_mean_squared_error: 4.3058
# Epoch 38/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7583 - mae: 4.0549 - root_mean_squared_error: 4.3311 - val_loss: 18.4554 - val_mae: 4.0112 - val_root_mean_squared_error: 4.2960
# Epoch 39/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7226 - mae: 4.0492 - root_mean_squared_error: 4.3269 - val_loss: 18.3694 - val_mae: 4.0015 - val_root_mean_squared_error: 4.2860
# Epoch 40/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.4405 - mae: 4.0163 - root_mean_squared_error: 4.2942 - val_loss: 18.2828 - val_mae: 3.9918 - val_root_mean_squared_error: 4.2758
# Epoch 41/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7109 - mae: 4.0473 - root_mean_squared_error: 4.3255 - val_loss: 18.1949 - val_mae: 3.9820 - val_root_mean_squared_error: 4.2655
# Epoch 42/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.2335 - mae: 3.9965 - root_mean_squared_error: 4.2700 - val_loss: 18.1066 - val_mae: 3.9721 - val_root_mean_squared_error: 4.2552
# Epoch 43/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.4457 - mae: 4.0201 - root_mean_squared_error: 4.2948 - val_loss: 18.0165 - val_mae: 3.9620 - val_root_mean_squared_error: 4.2446
# Epoch 44/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.3921 - mae: 4.0099 - root_mean_squared_error: 4.2885 - val_loss: 17.9259 - val_mae: 3.9519 - val_root_mean_squared_error: 4.2339
# Epoch 45/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.8908 - mae: 3.9631 - root_mean_squared_error: 4.2297 - val_loss: 17.8344 - val_mae: 3.9417 - val_root_mean_squared_error: 4.2231
# Epoch 46/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0504 - mae: 3.9796 - root_mean_squared_error: 4.2485 - val_loss: 17.7421 - val_mae: 3.9315 - val_root_mean_squared_error: 4.2121
# Epoch 47/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9005 - mae: 3.9577 - root_mean_squared_error: 4.2308 - val_loss: 17.6476 - val_mae: 3.9209 - val_root_mean_squared_error: 4.2009
# Epoch 48/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.7502 - mae: 3.9476 - root_mean_squared_error: 4.2128 - val_loss: 17.5534 - val_mae: 3.9105 - val_root_mean_squared_error: 4.1897
# Epoch 49/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9187 - mae: 3.9595 - root_mean_squared_error: 4.2330 - val_loss: 17.4584 - val_mae: 3.9001 - val_root_mean_squared_error: 4.1783
# Epoch 50/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.8168 - mae: 3.9554 - root_mean_squared_error: 4.2209 - val_loss: 17.3622 - val_mae: 3.8895 - val_root_mean_squared_error: 4.1668
# Epoch 51/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.7868 - mae: 3.9528 - root_mean_squared_error: 4.2174 - val_loss: 17.2648 - val_mae: 3.8788 - val_root_mean_squared_error: 4.1551
# Epoch 52/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5930 - mae: 3.9325 - root_mean_squared_error: 4.1944 - val_loss: 17.1665 - val_mae: 3.8681 - val_root_mean_squared_error: 4.1432
# Epoch 53/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.3813 - mae: 3.8989 - root_mean_squared_error: 4.1691 - val_loss: 17.0667 - val_mae: 3.8572 - val_root_mean_squared_error: 4.1312
# Epoch 54/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.3965 - mae: 3.9105 - root_mean_squared_error: 4.1708 - val_loss: 16.9658 - val_mae: 3.8463 - val_root_mean_squared_error: 4.1190
# Epoch 55/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9879 - mae: 3.8573 - root_mean_squared_error: 4.1215 - val_loss: 16.8645 - val_mae: 3.8354 - val_root_mean_squared_error: 4.1066
# Epoch 56/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9334 - mae: 3.8536 - root_mean_squared_error: 4.1149 - val_loss: 16.7622 - val_mae: 3.8243 - val_root_mean_squared_error: 4.0942
# Epoch 57/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.2849 - mae: 3.8868 - root_mean_squared_error: 4.1574 - val_loss: 16.6580 - val_mae: 3.8132 - val_root_mean_squared_error: 4.0814
# Epoch 58/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9838 - mae: 3.8654 - root_mean_squared_error: 4.1210 - val_loss: 16.5537 - val_mae: 3.8020 - val_root_mean_squared_error: 4.0686
# Epoch 59/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.7363 - mae: 3.8383 - root_mean_squared_error: 4.0910 - val_loss: 16.4487 - val_mae: 3.7908 - val_root_mean_squared_error: 4.0557
# Epoch 60/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.5425 - mae: 3.8158 - root_mean_squared_error: 4.0672 - val_loss: 16.3414 - val_mae: 3.7793 - val_root_mean_squared_error: 4.0424
# Epoch 61/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.6591 - mae: 3.8242 - root_mean_squared_error: 4.0815 - val_loss: 16.2334 - val_mae: 3.7679 - val_root_mean_squared_error: 4.0291
# Epoch 62/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.4295 - mae: 3.8112 - root_mean_squared_error: 4.0533 - val_loss: 16.1249 - val_mae: 3.7564 - val_root_mean_squared_error: 4.0156
# Epoch 63/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.3000 - mae: 3.7881 - root_mean_squared_error: 4.0373 - val_loss: 16.0153 - val_mae: 3.7446 - val_root_mean_squared_error: 4.0019
# Epoch 64/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.1633 - mae: 3.7752 - root_mean_squared_error: 4.0203 - val_loss: 15.9049 - val_mae: 3.7330 - val_root_mean_squared_error: 3.9881
# Epoch 65/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.2923 - mae: 3.7943 - root_mean_squared_error: 4.0363 - val_loss: 15.7933 - val_mae: 3.7211 - val_root_mean_squared_error: 3.9741
# Epoch 66/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.0791 - mae: 3.7706 - root_mean_squared_error: 4.0098 - val_loss: 15.6811 - val_mae: 3.7091 - val_root_mean_squared_error: 3.9599
# Epoch 67/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.9252 - mae: 3.7496 - root_mean_squared_error: 3.9906 - val_loss: 15.5683 - val_mae: 3.6970 - val_root_mean_squared_error: 3.9457
# Epoch 68/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6024 - mae: 3.7157 - root_mean_squared_error: 3.9499 - val_loss: 15.4549 - val_mae: 3.6848 - val_root_mean_squared_error: 3.9313
# Epoch 69/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6061 - mae: 3.7145 - root_mean_squared_error: 3.9504 - val_loss: 15.3396 - val_mae: 3.6724 - val_root_mean_squared_error: 3.9166
# Epoch 70/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6257 - mae: 3.7211 - root_mean_squared_error: 3.9529 - val_loss: 15.2240 - val_mae: 3.6600 - val_root_mean_squared_error: 3.9018
# Epoch 71/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.3499 - mae: 3.6902 - root_mean_squared_error: 3.9179 - val_loss: 15.1078 - val_mae: 3.6474 - val_root_mean_squared_error: 3.8869
# Epoch 72/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.2490 - mae: 3.6775 - root_mean_squared_error: 3.9050 - val_loss: 14.9910 - val_mae: 3.6347 - val_root_mean_squared_error: 3.8718
# Epoch 73/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.3771 - mae: 3.6988 - root_mean_squared_error: 3.9212 - val_loss: 14.8737 - val_mae: 3.6220 - val_root_mean_squared_error: 3.8566
# Epoch 74/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.9950 - mae: 3.6486 - root_mean_squared_error: 3.8723 - val_loss: 14.7581 - val_mae: 3.6095 - val_root_mean_squared_error: 3.8416
# Epoch 75/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.0867 - mae: 3.6644 - root_mean_squared_error: 3.8841 - val_loss: 14.6429 - val_mae: 3.5971 - val_root_mean_squared_error: 3.8266
# Epoch 76/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7203 - mae: 3.6202 - root_mean_squared_error: 3.8366 - val_loss: 14.5291 - val_mae: 3.5849 - val_root_mean_squared_error: 3.8117
# Epoch 77/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7772 - mae: 3.6265 - root_mean_squared_error: 3.8441 - val_loss: 14.4158 - val_mae: 3.5729 - val_root_mean_squared_error: 3.7968
# Epoch 78/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.8113 - mae: 3.6362 - root_mean_squared_error: 3.8484 - val_loss: 14.3031 - val_mae: 3.5609 - val_root_mean_squared_error: 3.7819
# Epoch 79/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.3694 - mae: 3.5851 - root_mean_squared_error: 3.7907 - val_loss: 14.1911 - val_mae: 3.5489 - val_root_mean_squared_error: 3.7671
# Epoch 80/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.1738 - mae: 3.5572 - root_mean_squared_error: 3.7647 - val_loss: 14.0791 - val_mae: 3.5369 - val_root_mean_squared_error: 3.7522
# Epoch 81/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.0975 - mae: 3.5517 - root_mean_squared_error: 3.7546 - val_loss: 13.9675 - val_mae: 3.5250 - val_root_mean_squared_error: 3.7373
# Epoch 82/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9740 - mae: 3.5400 - root_mean_squared_error: 3.7382 - val_loss: 13.8564 - val_mae: 3.5130 - val_root_mean_squared_error: 3.7224
# Epoch 83/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9513 - mae: 3.5403 - root_mean_squared_error: 3.7351 - val_loss: 13.7457 - val_mae: 3.5011 - val_root_mean_squared_error: 3.7075
# Epoch 84/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.9749 - mae: 3.5475 - root_mean_squared_error: 3.7382 - val_loss: 13.6351 - val_mae: 3.4891 - val_root_mean_squared_error: 3.6926
# Epoch 85/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.7104 - mae: 3.5099 - root_mean_squared_error: 3.7027 - val_loss: 13.5249 - val_mae: 3.4772 - val_root_mean_squared_error: 3.6776
# Epoch 86/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.6165 - mae: 3.5035 - root_mean_squared_error: 3.6900 - val_loss: 13.4160 - val_mae: 3.4653 - val_root_mean_squared_error: 3.6628
# Epoch 87/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.6115 - mae: 3.5066 - root_mean_squared_error: 3.6893 - val_loss: 13.3074 - val_mae: 3.4534 - val_root_mean_squared_error: 3.6479
# Epoch 88/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.4830 - mae: 3.4921 - root_mean_squared_error: 3.6719 - val_loss: 13.1991 - val_mae: 3.4415 - val_root_mean_squared_error: 3.6331
# Epoch 89/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.2340 - mae: 3.4569 - root_mean_squared_error: 3.6378 - val_loss: 13.0923 - val_mae: 3.4296 - val_root_mean_squared_error: 3.6183
# Epoch 90/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.3674 - mae: 3.4772 - root_mean_squared_error: 3.6559 - val_loss: 12.9850 - val_mae: 3.4177 - val_root_mean_squared_error: 3.6035
# Epoch 91/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1064 - mae: 3.4441 - root_mean_squared_error: 3.6202 - val_loss: 12.8786 - val_mae: 3.4058 - val_root_mean_squared_error: 3.5887
# Epoch 92/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.0768 - mae: 3.4422 - root_mean_squared_error: 3.6161 - val_loss: 12.7722 - val_mae: 3.3938 - val_root_mean_squared_error: 3.5738
# Epoch 93/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8890 - mae: 3.4192 - root_mean_squared_error: 3.5901 - val_loss: 12.6665 - val_mae: 3.3819 - val_root_mean_squared_error: 3.5590
# Epoch 94/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.6334 - mae: 3.3869 - root_mean_squared_error: 3.5543 - val_loss: 12.5613 - val_mae: 3.3699 - val_root_mean_squared_error: 3.5442
# Epoch 95/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.6273 - mae: 3.3914 - root_mean_squared_error: 3.5534 - val_loss: 12.4555 - val_mae: 3.3579 - val_root_mean_squared_error: 3.5292
# Epoch 96/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.5051 - mae: 3.3773 - root_mean_squared_error: 3.5362 - val_loss: 12.3517 - val_mae: 3.3459 - val_root_mean_squared_error: 3.5145
# Epoch 97/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.4676 - mae: 3.3734 - root_mean_squared_error: 3.5308 - val_loss: 12.2479 - val_mae: 3.3339 - val_root_mean_squared_error: 3.4997
# Epoch 98/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2876 - mae: 3.3507 - root_mean_squared_error: 3.5054 - val_loss: 12.1442 - val_mae: 3.3218 - val_root_mean_squared_error: 3.4849
# Epoch 99/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.1632 - mae: 3.3345 - root_mean_squared_error: 3.4875 - val_loss: 12.0403 - val_mae: 3.3096 - val_root_mean_squared_error: 3.4699
# Epoch 100/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.1791 - mae: 3.3410 - root_mean_squared_error: 3.4898 - val_loss: 11.9373 - val_mae: 3.2975 - val_root_mean_squared_error: 3.4550
# Epoch 101/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.9749 - mae: 3.3109 - root_mean_squared_error: 3.4604 - val_loss: 11.8348 - val_mae: 3.2853 - val_root_mean_squared_error: 3.4402
# Epoch 102/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.9713 - mae: 3.3153 - root_mean_squared_error: 3.4599 - val_loss: 11.7328 - val_mae: 3.2732 - val_root_mean_squared_error: 3.4253
# Epoch 103/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.8365 - mae: 3.2949 - root_mean_squared_error: 3.4404 - val_loss: 11.6323 - val_mae: 3.2610 - val_root_mean_squared_error: 3.4106
# Epoch 104/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7043 - mae: 3.2833 - root_mean_squared_error: 3.4211 - val_loss: 11.5321 - val_mae: 3.2489 - val_root_mean_squared_error: 3.3959
# Epoch 105/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.6829 - mae: 3.2840 - root_mean_squared_error: 3.4180 - val_loss: 11.4321 - val_mae: 3.2367 - val_root_mean_squared_error: 3.3811
# Epoch 106/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4352 - mae: 3.2489 - root_mean_squared_error: 3.3816 - val_loss: 11.3345 - val_mae: 3.2247 - val_root_mean_squared_error: 3.3667
# Epoch 107/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4271 - mae: 3.2483 - root_mean_squared_error: 3.3804 - val_loss: 11.2376 - val_mae: 3.2127 - val_root_mean_squared_error: 3.3523
# Epoch 108/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4359 - mae: 3.2521 - root_mean_squared_error: 3.3816 - val_loss: 11.1409 - val_mae: 3.2007 - val_root_mean_squared_error: 3.3378
# Epoch 109/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.2298 - mae: 3.2233 - root_mean_squared_error: 3.3511 - val_loss: 11.0456 - val_mae: 3.1887 - val_root_mean_squared_error: 3.3235
# Epoch 110/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.1793 - mae: 3.2177 - root_mean_squared_error: 3.3435 - val_loss: 10.9509 - val_mae: 3.1768 - val_root_mean_squared_error: 3.3092
# Epoch 111/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.0695 - mae: 3.2054 - root_mean_squared_error: 3.3271 - val_loss: 10.8581 - val_mae: 3.1649 - val_root_mean_squared_error: 3.2952
# Epoch 112/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0061 - mae: 3.1959 - root_mean_squared_error: 3.3175 - val_loss: 10.7652 - val_mae: 3.1531 - val_root_mean_squared_error: 3.2810
# Epoch 113/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.7765 - mae: 3.1651 - root_mean_squared_error: 3.2827 - val_loss: 10.6741 - val_mae: 3.1413 - val_root_mean_squared_error: 3.2671
# Epoch 114/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.6980 - mae: 3.1543 - root_mean_squared_error: 3.2708 - val_loss: 10.5851 - val_mae: 3.1296 - val_root_mean_squared_error: 3.2535
# Epoch 115/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.5918 - mae: 3.1402 - root_mean_squared_error: 3.2545 - val_loss: 10.4957 - val_mae: 3.1179 - val_root_mean_squared_error: 3.2397
# Epoch 116/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.6043 - mae: 3.1438 - root_mean_squared_error: 3.2564 - val_loss: 10.4079 - val_mae: 3.1064 - val_root_mean_squared_error: 3.2261
# Epoch 117/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.5217 - mae: 3.1329 - root_mean_squared_error: 3.2437 - val_loss: 10.3212 - val_mae: 3.0947 - val_root_mean_squared_error: 3.2127
# Epoch 118/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.4126 - mae: 3.1174 - root_mean_squared_error: 3.2268 - val_loss: 10.2343 - val_mae: 3.0831 - val_root_mean_squared_error: 3.1991
# Epoch 119/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.3325 - mae: 3.1040 - root_mean_squared_error: 3.2144 - val_loss: 10.1486 - val_mae: 3.0715 - val_root_mean_squared_error: 3.1857
# Epoch 120/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.2925 - mae: 3.1037 - root_mean_squared_error: 3.2081 - val_loss: 10.0640 - val_mae: 3.0600 - val_root_mean_squared_error: 3.1724
# Epoch 121/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.0681 - mae: 3.0697 - root_mean_squared_error: 3.1730 - val_loss: 9.9807 - val_mae: 3.0485 - val_root_mean_squared_error: 3.1592
# Epoch 122/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.0494 - mae: 3.0674 - root_mean_squared_error: 3.1701 - val_loss: 9.8976 - val_mae: 3.0370 - val_root_mean_squared_error: 3.1460
# Epoch 123/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9264 - mae: 3.0490 - root_mean_squared_error: 3.1506 - val_loss: 9.8154 - val_mae: 3.0255 - val_root_mean_squared_error: 3.1330
# Epoch 124/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8526 - mae: 3.0409 - root_mean_squared_error: 3.1389 - val_loss: 9.7338 - val_mae: 3.0141 - val_root_mean_squared_error: 3.1199
# Epoch 125/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8387 - mae: 3.0382 - root_mean_squared_error: 3.1367 - val_loss: 9.6524 - val_mae: 3.0026 - val_root_mean_squared_error: 3.1068
# Epoch 126/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7092 - mae: 3.0185 - root_mean_squared_error: 3.1159 - val_loss: 9.5726 - val_mae: 2.9912 - val_root_mean_squared_error: 3.0940
# Epoch 127/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6705 - mae: 3.0121 - root_mean_squared_error: 3.1097 - val_loss: 9.4922 - val_mae: 2.9796 - val_root_mean_squared_error: 3.0809
# Epoch 128/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5461 - mae: 2.9965 - root_mean_squared_error: 3.0897 - val_loss: 9.4130 - val_mae: 2.9682 - val_root_mean_squared_error: 3.0681
# Epoch 129/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4620 - mae: 2.9823 - root_mean_squared_error: 3.0760 - val_loss: 9.3343 - val_mae: 2.9567 - val_root_mean_squared_error: 3.0552
# Epoch 130/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4210 - mae: 2.9796 - root_mean_squared_error: 3.0693 - val_loss: 9.2553 - val_mae: 2.9451 - val_root_mean_squared_error: 3.0423
# Epoch 131/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3817 - mae: 2.9730 - root_mean_squared_error: 3.0629 - val_loss: 9.1765 - val_mae: 2.9335 - val_root_mean_squared_error: 3.0293
# Epoch 132/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1890 - mae: 2.9404 - root_mean_squared_error: 3.0313 - val_loss: 9.0994 - val_mae: 2.9220 - val_root_mean_squared_error: 3.0165
# Epoch 133/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1080 - mae: 2.9314 - root_mean_squared_error: 3.0179 - val_loss: 9.0220 - val_mae: 2.9104 - val_root_mean_squared_error: 3.0037
# Epoch 134/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0838 - mae: 2.9279 - root_mean_squared_error: 3.0139 - val_loss: 8.9449 - val_mae: 2.8988 - val_root_mean_squared_error: 2.9908
# Epoch 135/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9966 - mae: 2.9143 - root_mean_squared_error: 2.9994 - val_loss: 8.8678 - val_mae: 2.8871 - val_root_mean_squared_error: 2.9779
# Epoch 136/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8488 - mae: 2.8918 - root_mean_squared_error: 2.9747 - val_loss: 8.7910 - val_mae: 2.8754 - val_root_mean_squared_error: 2.9650
# Epoch 137/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8306 - mae: 2.8896 - root_mean_squared_error: 2.9716 - val_loss: 8.7150 - val_mae: 2.8637 - val_root_mean_squared_error: 2.9521
# Epoch 138/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8163 - mae: 2.8877 - root_mean_squared_error: 2.9692 - val_loss: 8.6391 - val_mae: 2.8520 - val_root_mean_squared_error: 2.9392
# Epoch 139/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6526 - mae: 2.8609 - root_mean_squared_error: 2.9415 - val_loss: 8.5640 - val_mae: 2.8402 - val_root_mean_squared_error: 2.9264
# Epoch 140/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5788 - mae: 2.8501 - root_mean_squared_error: 2.9290 - val_loss: 8.4892 - val_mae: 2.8285 - val_root_mean_squared_error: 2.9136
# Epoch 141/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5205 - mae: 2.8391 - root_mean_squared_error: 2.9190 - val_loss: 8.4139 - val_mae: 2.8166 - val_root_mean_squared_error: 2.9007
# Epoch 142/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4731 - mae: 2.8339 - root_mean_squared_error: 2.9109 - val_loss: 8.3390 - val_mae: 2.8048 - val_root_mean_squared_error: 2.8877
# Epoch 143/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3600 - mae: 2.8146 - root_mean_squared_error: 2.8914 - val_loss: 8.2644 - val_mae: 2.7929 - val_root_mean_squared_error: 2.8748
# Epoch 144/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3306 - mae: 2.8114 - root_mean_squared_error: 2.8863 - val_loss: 8.1901 - val_mae: 2.7809 - val_root_mean_squared_error: 2.8618
# Epoch 145/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2726 - mae: 2.8019 - root_mean_squared_error: 2.8761 - val_loss: 8.1159 - val_mae: 2.7689 - val_root_mean_squared_error: 2.8488
# Epoch 146/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1504 - mae: 2.7805 - root_mean_squared_error: 2.8549 - val_loss: 8.0418 - val_mae: 2.7569 - val_root_mean_squared_error: 2.8358
# Epoch 147/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0748 - mae: 2.7703 - root_mean_squared_error: 2.8416 - val_loss: 7.9678 - val_mae: 2.7448 - val_root_mean_squared_error: 2.8227
# Epoch 148/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9419 - mae: 2.7461 - root_mean_squared_error: 2.8181 - val_loss: 7.8942 - val_mae: 2.7328 - val_root_mean_squared_error: 2.8097
# Epoch 149/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9405 - mae: 2.7476 - root_mean_squared_error: 2.8179 - val_loss: 7.8204 - val_mae: 2.7206 - val_root_mean_squared_error: 2.7965
# Epoch 150/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9428 - mae: 2.7483 - root_mean_squared_error: 2.8183 - val_loss: 7.7468 - val_mae: 2.7084 - val_root_mean_squared_error: 2.7833
# Epoch 151/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8496 - mae: 2.7320 - root_mean_squared_error: 2.8017 - val_loss: 7.6737 - val_mae: 2.6962 - val_root_mean_squared_error: 2.7701
# Epoch 152/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6328 - mae: 2.6962 - root_mean_squared_error: 2.7627 - val_loss: 7.6010 - val_mae: 2.6840 - val_root_mean_squared_error: 2.7570
# Epoch 153/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5872 - mae: 2.6878 - root_mean_squared_error: 2.7545 - val_loss: 7.5283 - val_mae: 2.6717 - val_root_mean_squared_error: 2.7438
# Epoch 154/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4414 - mae: 2.6597 - root_mean_squared_error: 2.7278 - val_loss: 7.4561 - val_mae: 2.6593 - val_root_mean_squared_error: 2.7306
# Epoch 155/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4563 - mae: 2.6648 - root_mean_squared_error: 2.7306 - val_loss: 7.3834 - val_mae: 2.6469 - val_root_mean_squared_error: 2.7172
# Epoch 156/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4093 - mae: 2.6577 - root_mean_squared_error: 2.7220 - val_loss: 7.3115 - val_mae: 2.6345 - val_root_mean_squared_error: 2.7040
# Epoch 157/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3145 - mae: 2.6413 - root_mean_squared_error: 2.7045 - val_loss: 7.2397 - val_mae: 2.6220 - val_root_mean_squared_error: 2.6907
# Epoch 158/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2637 - mae: 2.6323 - root_mean_squared_error: 2.6951 - val_loss: 7.1679 - val_mae: 2.6096 - val_root_mean_squared_error: 2.6773
# Epoch 159/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1719 - mae: 2.6156 - root_mean_squared_error: 2.6780 - val_loss: 7.0965 - val_mae: 2.5970 - val_root_mean_squared_error: 2.6639
# Epoch 160/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1438 - mae: 2.6112 - root_mean_squared_error: 2.6728 - val_loss: 7.0253 - val_mae: 2.5844 - val_root_mean_squared_error: 2.6505
# Epoch 161/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0630 - mae: 2.5950 - root_mean_squared_error: 2.6576 - val_loss: 6.9541 - val_mae: 2.5717 - val_root_mean_squared_error: 2.6371
# Epoch 162/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9474 - mae: 2.5751 - root_mean_squared_error: 2.6358 - val_loss: 6.8833 - val_mae: 2.5591 - val_root_mean_squared_error: 2.6236
# Epoch 163/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8625 - mae: 2.5611 - root_mean_squared_error: 2.6195 - val_loss: 6.8125 - val_mae: 2.5464 - val_root_mean_squared_error: 2.6101
# Epoch 164/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8061 - mae: 2.5500 - root_mean_squared_error: 2.6088 - val_loss: 6.7422 - val_mae: 2.5336 - val_root_mean_squared_error: 2.5966
# Epoch 165/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7082 - mae: 2.5304 - root_mean_squared_error: 2.5900 - val_loss: 6.6718 - val_mae: 2.5208 - val_root_mean_squared_error: 2.5830
# Epoch 166/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7185 - mae: 2.5352 - root_mean_squared_error: 2.5920 - val_loss: 6.6016 - val_mae: 2.5079 - val_root_mean_squared_error: 2.5694
# Epoch 167/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6257 - mae: 2.5162 - root_mean_squared_error: 2.5740 - val_loss: 6.5317 - val_mae: 2.4950 - val_root_mean_squared_error: 2.5557
# Epoch 168/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5464 - mae: 2.5045 - root_mean_squared_error: 2.5586 - val_loss: 6.4620 - val_mae: 2.4821 - val_root_mean_squared_error: 2.5420
# Epoch 169/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4660 - mae: 2.4880 - root_mean_squared_error: 2.5428 - val_loss: 6.3926 - val_mae: 2.4691 - val_root_mean_squared_error: 2.5284
# Epoch 170/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4217 - mae: 2.4790 - root_mean_squared_error: 2.5341 - val_loss: 6.3232 - val_mae: 2.4561 - val_root_mean_squared_error: 2.5146
# Epoch 171/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3708 - mae: 2.4694 - root_mean_squared_error: 2.5240 - val_loss: 6.2541 - val_mae: 2.4430 - val_root_mean_squared_error: 2.5008
# Epoch 172/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2921 - mae: 2.4547 - root_mean_squared_error: 2.5084 - val_loss: 6.1855 - val_mae: 2.4299 - val_root_mean_squared_error: 2.4871
# Epoch 173/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2123 - mae: 2.4393 - root_mean_squared_error: 2.4924 - val_loss: 6.1169 - val_mae: 2.4167 - val_root_mean_squared_error: 2.4732
# Epoch 174/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1113 - mae: 2.4203 - root_mean_squared_error: 2.4721 - val_loss: 6.0484 - val_mae: 2.4035 - val_root_mean_squared_error: 2.4593
# Epoch 175/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0865 - mae: 2.4153 - root_mean_squared_error: 2.4671 - val_loss: 5.9802 - val_mae: 2.3903 - val_root_mean_squared_error: 2.4454
# Epoch 176/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9859 - mae: 2.3957 - root_mean_squared_error: 2.4466 - val_loss: 5.9121 - val_mae: 2.3769 - val_root_mean_squared_error: 2.4315
# Epoch 177/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9319 - mae: 2.3857 - root_mean_squared_error: 2.4355 - val_loss: 5.8444 - val_mae: 2.3636 - val_root_mean_squared_error: 2.4175
# Epoch 178/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8286 - mae: 2.3649 - root_mean_squared_error: 2.4142 - val_loss: 5.7769 - val_mae: 2.3502 - val_root_mean_squared_error: 2.4035
# Epoch 179/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7393 - mae: 2.3465 - root_mean_squared_error: 2.3957 - val_loss: 5.7101 - val_mae: 2.3368 - val_root_mean_squared_error: 2.3896
# Epoch 180/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6877 - mae: 2.3369 - root_mean_squared_error: 2.3849 - val_loss: 5.6438 - val_mae: 2.3235 - val_root_mean_squared_error: 2.3757
# Epoch 181/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6377 - mae: 2.3257 - root_mean_squared_error: 2.3744 - val_loss: 5.5788 - val_mae: 2.3104 - val_root_mean_squared_error: 2.3619
# Epoch 182/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5852 - mae: 2.3160 - root_mean_squared_error: 2.3633 - val_loss: 5.5148 - val_mae: 2.2976 - val_root_mean_squared_error: 2.3484
# Epoch 183/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5064 - mae: 2.2996 - root_mean_squared_error: 2.3466 - val_loss: 5.4516 - val_mae: 2.2848 - val_root_mean_squared_error: 2.3349
# Epoch 184/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4365 - mae: 2.2861 - root_mean_squared_error: 2.3316 - val_loss: 5.3895 - val_mae: 2.2722 - val_root_mean_squared_error: 2.3215
# Epoch 185/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3992 - mae: 2.2778 - root_mean_squared_error: 2.3236 - val_loss: 5.3282 - val_mae: 2.2596 - val_root_mean_squared_error: 2.3083
# Epoch 186/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3133 - mae: 2.2599 - root_mean_squared_error: 2.3050 - val_loss: 5.2674 - val_mae: 2.2471 - val_root_mean_squared_error: 2.2951
# Epoch 187/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2652 - mae: 2.2498 - root_mean_squared_error: 2.2946 - val_loss: 5.2074 - val_mae: 2.2348 - val_root_mean_squared_error: 2.2820
# Epoch 188/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2219 - mae: 2.2398 - root_mean_squared_error: 2.2851 - val_loss: 5.1483 - val_mae: 2.2225 - val_root_mean_squared_error: 2.2690
# Epoch 189/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1297 - mae: 2.2224 - root_mean_squared_error: 2.2649 - val_loss: 5.0898 - val_mae: 2.2103 - val_root_mean_squared_error: 2.2561
# Epoch 190/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0962 - mae: 2.2147 - root_mean_squared_error: 2.2575 - val_loss: 5.0323 - val_mae: 2.1983 - val_root_mean_squared_error: 2.2433
# Epoch 191/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9750 - mae: 2.1892 - root_mean_squared_error: 2.2305 - val_loss: 4.9757 - val_mae: 2.1862 - val_root_mean_squared_error: 2.2306
# Epoch 192/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9717 - mae: 2.1881 - root_mean_squared_error: 2.2297 - val_loss: 4.9194 - val_mae: 2.1743 - val_root_mean_squared_error: 2.2180
# Epoch 193/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8945 - mae: 2.1719 - root_mean_squared_error: 2.2123 - val_loss: 4.8642 - val_mae: 2.1625 - val_root_mean_squared_error: 2.2055
# Epoch 194/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8692 - mae: 2.1662 - root_mean_squared_error: 2.2066 - val_loss: 4.8102 - val_mae: 2.1509 - val_root_mean_squared_error: 2.1932
# Epoch 195/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7778 - mae: 2.1462 - root_mean_squared_error: 2.1858 - val_loss: 4.7567 - val_mae: 2.1393 - val_root_mean_squared_error: 2.1810
# Epoch 196/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7387 - mae: 2.1382 - root_mean_squared_error: 2.1769 - val_loss: 4.7042 - val_mae: 2.1278 - val_root_mean_squared_error: 2.1689
# Epoch 197/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6617 - mae: 2.1212 - root_mean_squared_error: 2.1591 - val_loss: 4.6523 - val_mae: 2.1163 - val_root_mean_squared_error: 2.1569
# Epoch 198/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6510 - mae: 2.1182 - root_mean_squared_error: 2.1566 - val_loss: 4.6012 - val_mae: 2.1050 - val_root_mean_squared_error: 2.1450
# Epoch 199/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5597 - mae: 2.0981 - root_mean_squared_error: 2.1353 - val_loss: 4.5507 - val_mae: 2.0938 - val_root_mean_squared_error: 2.1332
# Epoch 200/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5526 - mae: 2.0961 - root_mean_squared_error: 2.1337 - val_loss: 4.5012 - val_mae: 2.0827 - val_root_mean_squared_error: 2.1216
# Epoch 201/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4600 - mae: 2.0756 - root_mean_squared_error: 2.1119 - val_loss: 4.4519 - val_mae: 2.0716 - val_root_mean_squared_error: 2.1100
# Epoch 202/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4190 - mae: 2.0654 - root_mean_squared_error: 2.1021 - val_loss: 4.4034 - val_mae: 2.0605 - val_root_mean_squared_error: 2.0984
# Epoch 203/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3738 - mae: 2.0561 - root_mean_squared_error: 2.0913 - val_loss: 4.3556 - val_mae: 2.0496 - val_root_mean_squared_error: 2.0870
# Epoch 204/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3291 - mae: 2.0455 - root_mean_squared_error: 2.0806 - val_loss: 4.3083 - val_mae: 2.0387 - val_root_mean_squared_error: 2.0756
# Epoch 205/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2786 - mae: 2.0334 - root_mean_squared_error: 2.0685 - val_loss: 4.2616 - val_mae: 2.0279 - val_root_mean_squared_error: 2.0644
# Epoch 206/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2409 - mae: 2.0246 - root_mean_squared_error: 2.0593 - val_loss: 4.2156 - val_mae: 2.0171 - val_root_mean_squared_error: 2.0532
# Epoch 207/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2013 - mae: 2.0152 - root_mean_squared_error: 2.0497 - val_loss: 4.1702 - val_mae: 2.0065 - val_root_mean_squared_error: 2.0421
# Epoch 208/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1705 - mae: 2.0092 - root_mean_squared_error: 2.0422 - val_loss: 4.1256 - val_mae: 1.9959 - val_root_mean_squared_error: 2.0312
# Epoch 209/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0864 - mae: 1.9882 - root_mean_squared_error: 2.0215 - val_loss: 4.0814 - val_mae: 1.9854 - val_root_mean_squared_error: 2.0202
# Epoch 210/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0365 - mae: 1.9760 - root_mean_squared_error: 2.0091 - val_loss: 4.0378 - val_mae: 1.9749 - val_root_mean_squared_error: 2.0094
# Epoch 211/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0273 - mae: 1.9739 - root_mean_squared_error: 2.0068 - val_loss: 3.9946 - val_mae: 1.9645 - val_root_mean_squared_error: 1.9986
# Epoch 212/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9953 - mae: 1.9659 - root_mean_squared_error: 1.9988 - val_loss: 3.9521 - val_mae: 1.9542 - val_root_mean_squared_error: 1.9880
# Epoch 213/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9300 - mae: 1.9510 - root_mean_squared_error: 1.9824 - val_loss: 3.9100 - val_mae: 1.9438 - val_root_mean_squared_error: 1.9774
# Epoch 214/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8982 - mae: 1.9425 - root_mean_squared_error: 1.9744 - val_loss: 3.8686 - val_mae: 1.9336 - val_root_mean_squared_error: 1.9669
# Epoch 215/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8300 - mae: 1.9257 - root_mean_squared_error: 1.9570 - val_loss: 3.8279 - val_mae: 1.9235 - val_root_mean_squared_error: 1.9565
# Epoch 216/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7955 - mae: 1.9164 - root_mean_squared_error: 1.9482 - val_loss: 3.7875 - val_mae: 1.9134 - val_root_mean_squared_error: 1.9462
# Epoch 217/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7677 - mae: 1.9092 - root_mean_squared_error: 1.9411 - val_loss: 3.7480 - val_mae: 1.9034 - val_root_mean_squared_error: 1.9360
# Epoch 218/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7195 - mae: 1.8975 - root_mean_squared_error: 1.9286 - val_loss: 3.7089 - val_mae: 1.8935 - val_root_mean_squared_error: 1.9259
# Epoch 219/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6780 - mae: 1.8868 - root_mean_squared_error: 1.9178 - val_loss: 3.6702 - val_mae: 1.8836 - val_root_mean_squared_error: 1.9158
# Epoch 220/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6560 - mae: 1.8814 - root_mean_squared_error: 1.9121 - val_loss: 3.6323 - val_mae: 1.8738 - val_root_mean_squared_error: 1.9059
# Epoch 221/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6257 - mae: 1.8731 - root_mean_squared_error: 1.9041 - val_loss: 3.5947 - val_mae: 1.8641 - val_root_mean_squared_error: 1.8960
# Epoch 222/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5808 - mae: 1.8618 - root_mean_squared_error: 1.8923 - val_loss: 3.5581 - val_mae: 1.8545 - val_root_mean_squared_error: 1.8863
# Epoch 223/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5771 - mae: 1.8608 - root_mean_squared_error: 1.8913 - val_loss: 3.5218 - val_mae: 1.8449 - val_root_mean_squared_error: 1.8766
# Epoch 224/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5038 - mae: 1.8417 - root_mean_squared_error: 1.8718 - val_loss: 3.4861 - val_mae: 1.8355 - val_root_mean_squared_error: 1.8671
# Epoch 225/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4945 - mae: 1.8390 - root_mean_squared_error: 1.8693 - val_loss: 3.4507 - val_mae: 1.8260 - val_root_mean_squared_error: 1.8576
# Epoch 226/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4405 - mae: 1.8254 - root_mean_squared_error: 1.8548 - val_loss: 3.4161 - val_mae: 1.8167 - val_root_mean_squared_error: 1.8483
# Epoch 227/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3789 - mae: 1.8082 - root_mean_squared_error: 1.8382 - val_loss: 3.3815 - val_mae: 1.8074 - val_root_mean_squared_error: 1.8389
# Epoch 228/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3664 - mae: 1.8051 - root_mean_squared_error: 1.8348 - val_loss: 3.3476 - val_mae: 1.7981 - val_root_mean_squared_error: 1.8296
# Epoch 229/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3206 - mae: 1.7921 - root_mean_squared_error: 1.8223 - val_loss: 3.3141 - val_mae: 1.7889 - val_root_mean_squared_error: 1.8205
# Epoch 230/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3128 - mae: 1.7905 - root_mean_squared_error: 1.8201 - val_loss: 3.2806 - val_mae: 1.7797 - val_root_mean_squared_error: 1.8112
# Epoch 231/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2578 - mae: 1.7745 - root_mean_squared_error: 1.8049 - val_loss: 3.2481 - val_mae: 1.7707 - val_root_mean_squared_error: 1.8022
# Epoch 232/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2296 - mae: 1.7670 - root_mean_squared_error: 1.7971 - val_loss: 3.2155 - val_mae: 1.7616 - val_root_mean_squared_error: 1.7932
# Epoch 233/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1876 - mae: 1.7546 - root_mean_squared_error: 1.7854 - val_loss: 3.1836 - val_mae: 1.7526 - val_root_mean_squared_error: 1.7843
# Epoch 234/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1853 - mae: 1.7549 - root_mean_squared_error: 1.7847 - val_loss: 3.1518 - val_mae: 1.7436 - val_root_mean_squared_error: 1.7753
# Epoch 235/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1300 - mae: 1.7393 - root_mean_squared_error: 1.7692 - val_loss: 3.1203 - val_mae: 1.7347 - val_root_mean_squared_error: 1.7664
# Epoch 236/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1125 - mae: 1.7339 - root_mean_squared_error: 1.7642 - val_loss: 3.0894 - val_mae: 1.7258 - val_root_mean_squared_error: 1.7577
# Epoch 237/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0768 - mae: 1.7227 - root_mean_squared_error: 1.7541 - val_loss: 3.0587 - val_mae: 1.7170 - val_root_mean_squared_error: 1.7489
# Epoch 238/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0252 - mae: 1.7083 - root_mean_squared_error: 1.7393 - val_loss: 3.0282 - val_mae: 1.7081 - val_root_mean_squared_error: 1.7402
# Epoch 239/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9991 - mae: 1.7002 - root_mean_squared_error: 1.7318 - val_loss: 2.9979 - val_mae: 1.6993 - val_root_mean_squared_error: 1.7314
# Epoch 240/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9892 - mae: 1.6984 - root_mean_squared_error: 1.7289 - val_loss: 2.9679 - val_mae: 1.6905 - val_root_mean_squared_error: 1.7228
# Epoch 241/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9528 - mae: 1.6882 - root_mean_squared_error: 1.7184 - val_loss: 2.9379 - val_mae: 1.6816 - val_root_mean_squared_error: 1.7140
# Epoch 242/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9334 - mae: 1.6815 - root_mean_squared_error: 1.7127 - val_loss: 2.9083 - val_mae: 1.6728 - val_root_mean_squared_error: 1.7054
# Epoch 243/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8884 - mae: 1.6677 - root_mean_squared_error: 1.6995 - val_loss: 2.8788 - val_mae: 1.6640 - val_root_mean_squared_error: 1.6967
# Epoch 244/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8685 - mae: 1.6617 - root_mean_squared_error: 1.6937 - val_loss: 2.8498 - val_mae: 1.6553 - val_root_mean_squared_error: 1.6881
# Epoch 245/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8219 - mae: 1.6479 - root_mean_squared_error: 1.6799 - val_loss: 2.8209 - val_mae: 1.6466 - val_root_mean_squared_error: 1.6796
# Epoch 246/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7845 - mae: 1.6363 - root_mean_squared_error: 1.6687 - val_loss: 2.7922 - val_mae: 1.6378 - val_root_mean_squared_error: 1.6710
# Epoch 247/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7651 - mae: 1.6307 - root_mean_squared_error: 1.6628 - val_loss: 2.7636 - val_mae: 1.6291 - val_root_mean_squared_error: 1.6624
# Epoch 248/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7427 - mae: 1.6244 - root_mean_squared_error: 1.6561 - val_loss: 2.7351 - val_mae: 1.6204 - val_root_mean_squared_error: 1.6538
# Epoch 249/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7331 - mae: 1.6208 - root_mean_squared_error: 1.6532 - val_loss: 2.7069 - val_mae: 1.6117 - val_root_mean_squared_error: 1.6453
# Epoch 250/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6975 - mae: 1.6101 - root_mean_squared_error: 1.6424 - val_loss: 2.6791 - val_mae: 1.6030 - val_root_mean_squared_error: 1.6368
# Epoch 251/500
# ...
# Epoch 418/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1717 - mae: 0.3409 - root_mean_squared_error: 0.4143 - val_loss: 0.1759 - val_mae: 0.3461 - val_root_mean_squared_error: 0.4194
# Epoch 419/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1725 - mae: 0.3425 - root_mean_squared_error: 0.4154 - val_loss: 0.1727 - val_mae: 0.3426 - val_root_mean_squared_error: 0.4155
# Epoch 420/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1663 - mae: 0.3366 - root_mean_squared_error: 0.4078 - val_loss: 0.1695 - val_mae: 0.3393 - val_root_mean_squared_error: 0.4117
# Epoch 421/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1602 - mae: 0.3286 - root_mean_squared_error: 0.4002 - val_loss: 0.1665 - val_mae: 0.3361 - val_root_mean_squared_error: 0.4080
# Epoch 422/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1596 - mae: 0.3289 - root_mean_squared_error: 0.3995 - val_loss: 0.1635 - val_mae: 0.3329 - val_root_mean_squared_error: 0.4044
# Epoch 423/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1552 - mae: 0.3254 - root_mean_squared_error: 0.3940 - val_loss: 0.1607 - val_mae: 0.3299 - val_root_mean_squared_error: 0.4008
# Epoch 424/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1577 - mae: 0.3264 - root_mean_squared_error: 0.3971 - val_loss: 0.1580 - val_mae: 0.3270 - val_root_mean_squared_error: 0.3974
# Epoch 425/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1504 - mae: 0.3173 - root_mean_squared_error: 0.3878 - val_loss: 0.1553 - val_mae: 0.3242 - val_root_mean_squared_error: 0.3941
# Epoch 426/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1467 - mae: 0.3149 - root_mean_squared_error: 0.3830 - val_loss: 0.1527 - val_mae: 0.3215 - val_root_mean_squared_error: 0.3908
# Epoch 427/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1505 - mae: 0.3175 - root_mean_squared_error: 0.3879 - val_loss: 0.1503 - val_mae: 0.3189 - val_root_mean_squared_error: 0.3876
# Epoch 428/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1452 - mae: 0.3142 - root_mean_squared_error: 0.3810 - val_loss: 0.1479 - val_mae: 0.3163 - val_root_mean_squared_error: 0.3845
# Epoch 429/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1448 - mae: 0.3143 - root_mean_squared_error: 0.3805 - val_loss: 0.1456 - val_mae: 0.3139 - val_root_mean_squared_error: 0.3816
# Epoch 430/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1392 - mae: 0.3058 - root_mean_squared_error: 0.3731 - val_loss: 0.1434 - val_mae: 0.3116 - val_root_mean_squared_error: 0.3787
# Epoch 431/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1368 - mae: 0.3046 - root_mean_squared_error: 0.3698 - val_loss: 0.1413 - val_mae: 0.3094 - val_root_mean_squared_error: 0.3759
# Epoch 432/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1348 - mae: 0.3017 - root_mean_squared_error: 0.3672 - val_loss: 0.1393 - val_mae: 0.3072 - val_root_mean_squared_error: 0.3732
# Epoch 433/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1344 - mae: 0.3018 - root_mean_squared_error: 0.3666 - val_loss: 0.1374 - val_mae: 0.3051 - val_root_mean_squared_error: 0.3706
# Epoch 434/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1318 - mae: 0.2995 - root_mean_squared_error: 0.3631 - val_loss: 0.1355 - val_mae: 0.3031 - val_root_mean_squared_error: 0.3681
# Epoch 435/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1322 - mae: 0.2988 - root_mean_squared_error: 0.3635 - val_loss: 0.1337 - val_mae: 0.3012 - val_root_mean_squared_error: 0.3657
# Epoch 436/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1290 - mae: 0.2940 - root_mean_squared_error: 0.3592 - val_loss: 0.1320 - val_mae: 0.2994 - val_root_mean_squared_error: 0.3633
# Epoch 437/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1271 - mae: 0.2916 - root_mean_squared_error: 0.3565 - val_loss: 0.1304 - val_mae: 0.2976 - val_root_mean_squared_error: 0.3611
# Epoch 438/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1226 - mae: 0.2853 - root_mean_squared_error: 0.3502 - val_loss: 0.1288 - val_mae: 0.2959 - val_root_mean_squared_error: 0.3589
# Epoch 439/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1246 - mae: 0.2903 - root_mean_squared_error: 0.3530 - val_loss: 0.1273 - val_mae: 0.2942 - val_root_mean_squared_error: 0.3568
# Epoch 440/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1235 - mae: 0.2883 - root_mean_squared_error: 0.3514 - val_loss: 0.1259 - val_mae: 0.2926 - val_root_mean_squared_error: 0.3548
# Epoch 441/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1194 - mae: 0.2838 - root_mean_squared_error: 0.3456 - val_loss: 0.1246 - val_mae: 0.2911 - val_root_mean_squared_error: 0.3530
# Epoch 442/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1220 - mae: 0.2868 - root_mean_squared_error: 0.3492 - val_loss: 0.1233 - val_mae: 0.2896 - val_root_mean_squared_error: 0.3512
# Epoch 443/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1178 - mae: 0.2806 - root_mean_squared_error: 0.3433 - val_loss: 0.1221 - val_mae: 0.2882 - val_root_mean_squared_error: 0.3495
# Epoch 444/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1187 - mae: 0.2829 - root_mean_squared_error: 0.3445 - val_loss: 0.1210 - val_mae: 0.2868 - val_root_mean_squared_error: 0.3479
# Epoch 445/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1144 - mae: 0.2767 - root_mean_squared_error: 0.3382 - val_loss: 0.1200 - val_mae: 0.2854 - val_root_mean_squared_error: 0.3463
# Epoch 446/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1148 - mae: 0.2773 - root_mean_squared_error: 0.3389 - val_loss: 0.1189 - val_mae: 0.2841 - val_root_mean_squared_error: 0.3449
# Epoch 447/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1114 - mae: 0.2726 - root_mean_squared_error: 0.3337 - val_loss: 0.1180 - val_mae: 0.2829 - val_root_mean_squared_error: 0.3435
# Epoch 448/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1134 - mae: 0.2761 - root_mean_squared_error: 0.3368 - val_loss: 0.1171 - val_mae: 0.2817 - val_root_mean_squared_error: 0.3423
# Epoch 449/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1147 - mae: 0.2773 - root_mean_squared_error: 0.3386 - val_loss: 0.1163 - val_mae: 0.2806 - val_root_mean_squared_error: 0.3410
# Epoch 450/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1113 - mae: 0.2728 - root_mean_squared_error: 0.3336 - val_loss: 0.1155 - val_mae: 0.2795 - val_root_mean_squared_error: 0.3399
# Epoch 451/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1098 - mae: 0.2718 - root_mean_squared_error: 0.3313 - val_loss: 0.1148 - val_mae: 0.2785 - val_root_mean_squared_error: 0.3388
# Epoch 452/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1096 - mae: 0.2701 - root_mean_squared_error: 0.3310 - val_loss: 0.1141 - val_mae: 0.2776 - val_root_mean_squared_error: 0.3378
# Epoch 453/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1078 - mae: 0.2690 - root_mean_squared_error: 0.3282 - val_loss: 0.1135 - val_mae: 0.2766 - val_root_mean_squared_error: 0.3368
# Epoch 454/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1109 - mae: 0.2733 - root_mean_squared_error: 0.3330 - val_loss: 0.1129 - val_mae: 0.2758 - val_root_mean_squared_error: 0.3360
# Epoch 455/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1071 - mae: 0.2673 - root_mean_squared_error: 0.3273 - val_loss: 0.1123 - val_mae: 0.2750 - val_root_mean_squared_error: 0.3351
# Epoch 456/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1079 - mae: 0.2692 - root_mean_squared_error: 0.3285 - val_loss: 0.1118 - val_mae: 0.2742 - val_root_mean_squared_error: 0.3344
# Epoch 457/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1068 - mae: 0.2668 - root_mean_squared_error: 0.3267 - val_loss: 0.1114 - val_mae: 0.2735 - val_root_mean_squared_error: 0.3337
# Epoch 458/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1058 - mae: 0.2657 - root_mean_squared_error: 0.3253 - val_loss: 0.1109 - val_mae: 0.2728 - val_root_mean_squared_error: 0.3331
# Epoch 459/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1102 - mae: 0.2712 - root_mean_squared_error: 0.3320 - val_loss: 0.1105 - val_mae: 0.2723 - val_root_mean_squared_error: 0.3325
# Epoch 460/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1069 - mae: 0.2669 - root_mean_squared_error: 0.3269 - val_loss: 0.1102 - val_mae: 0.2717 - val_root_mean_squared_error: 0.3319
# Epoch 461/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1067 - mae: 0.2661 - root_mean_squared_error: 0.3266 - val_loss: 0.1098 - val_mae: 0.2712 - val_root_mean_squared_error: 0.3314
# Epoch 462/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1054 - mae: 0.2645 - root_mean_squared_error: 0.3246 - val_loss: 0.1095 - val_mae: 0.2707 - val_root_mean_squared_error: 0.3310
# Epoch 463/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1038 - mae: 0.2624 - root_mean_squared_error: 0.3222 - val_loss: 0.1093 - val_mae: 0.2703 - val_root_mean_squared_error: 0.3306
# Epoch 464/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1067 - mae: 0.2667 - root_mean_squared_error: 0.3266 - val_loss: 0.1090 - val_mae: 0.2699 - val_root_mean_squared_error: 0.3302
# Epoch 465/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1048 - mae: 0.2650 - root_mean_squared_error: 0.3237 - val_loss: 0.1088 - val_mae: 0.2695 - val_root_mean_squared_error: 0.3298
# Epoch 466/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1032 - mae: 0.2609 - root_mean_squared_error: 0.3213 - val_loss: 0.1086 - val_mae: 0.2691 - val_root_mean_squared_error: 0.3295
# Epoch 467/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1021 - mae: 0.2600 - root_mean_squared_error: 0.3196 - val_loss: 0.1084 - val_mae: 0.2688 - val_root_mean_squared_error: 0.3293
# Epoch 468/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1053 - mae: 0.2635 - root_mean_squared_error: 0.3245 - val_loss: 0.1082 - val_mae: 0.2685 - val_root_mean_squared_error: 0.3290
# Epoch 469/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1044 - mae: 0.2640 - root_mean_squared_error: 0.3231 - val_loss: 0.1081 - val_mae: 0.2682 - val_root_mean_squared_error: 0.3288
# Epoch 470/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1056 - mae: 0.2636 - root_mean_squared_error: 0.3249 - val_loss: 0.1080 - val_mae: 0.2679 - val_root_mean_squared_error: 0.3286
# Epoch 471/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1052 - mae: 0.2640 - root_mean_squared_error: 0.3243 - val_loss: 0.1079 - val_mae: 0.2677 - val_root_mean_squared_error: 0.3284
# Epoch 472/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1050 - mae: 0.2622 - root_mean_squared_error: 0.3240 - val_loss: 0.1078 - val_mae: 0.2675 - val_root_mean_squared_error: 0.3283
# Epoch 473/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1017 - mae: 0.2595 - root_mean_squared_error: 0.3189 - val_loss: 0.1077 - val_mae: 0.2673 - val_root_mean_squared_error: 0.3281
# Epoch 474/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1027 - mae: 0.2597 - root_mean_squared_error: 0.3204 - val_loss: 0.1076 - val_mae: 0.2671 - val_root_mean_squared_error: 0.3280
# Epoch 475/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1018 - mae: 0.2588 - root_mean_squared_error: 0.3190 - val_loss: 0.1075 - val_mae: 0.2669 - val_root_mean_squared_error: 0.3279
# Epoch 476/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1022 - mae: 0.2590 - root_mean_squared_error: 0.3197 - val_loss: 0.1075 - val_mae: 0.2668 - val_root_mean_squared_error: 0.3278
# Epoch 477/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1013 - mae: 0.2579 - root_mean_squared_error: 0.3182 - val_loss: 0.1074 - val_mae: 0.2666 - val_root_mean_squared_error: 0.3278
# Epoch 478/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1019 - mae: 0.2586 - root_mean_squared_error: 0.3192 - val_loss: 0.1074 - val_mae: 0.2666 - val_root_mean_squared_error: 0.3277
# Epoch 479/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - mae: 0.2620 - root_mean_squared_error: 0.3227 - val_loss: 0.1073 - val_mae: 0.2664 - val_root_mean_squared_error: 0.3276
# Epoch 480/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1034 - mae: 0.2614 - root_mean_squared_error: 0.3215 - val_loss: 0.1073 - val_mae: 0.2663 - val_root_mean_squared_error: 0.3276
# Epoch 481/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1043 - mae: 0.2624 - root_mean_squared_error: 0.3229 - val_loss: 0.1073 - val_mae: 0.2662 - val_root_mean_squared_error: 0.3275
# Epoch 482/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1044 - mae: 0.2614 - root_mean_squared_error: 0.3230 - val_loss: 0.1073 - val_mae: 0.2661 - val_root_mean_squared_error: 0.3275
# Epoch 483/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - mae: 0.2614 - root_mean_squared_error: 0.3226 - val_loss: 0.1072 - val_mae: 0.2660 - val_root_mean_squared_error: 0.3275
# Epoch 484/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1009 - mae: 0.2579 - root_mean_squared_error: 0.3177 - val_loss: 0.1072 - val_mae: 0.2660 - val_root_mean_squared_error: 0.3274
# Epoch 485/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1026 - mae: 0.2597 - root_mean_squared_error: 0.3204 - val_loss: 0.1072 - val_mae: 0.2659 - val_root_mean_squared_error: 0.3274
# Epoch 486/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1031 - mae: 0.2598 - root_mean_squared_error: 0.3211 - val_loss: 0.1072 - val_mae: 0.2658 - val_root_mean_squared_error: 0.3274
# Epoch 487/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1048 - mae: 0.2623 - root_mean_squared_error: 0.3238 - val_loss: 0.1072 - val_mae: 0.2658 - val_root_mean_squared_error: 0.3274
# Epoch 488/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1034 - mae: 0.2599 - root_mean_squared_error: 0.3215 - val_loss: 0.1072 - val_mae: 0.2657 - val_root_mean_squared_error: 0.3274
# Epoch 489/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1013 - mae: 0.2580 - root_mean_squared_error: 0.3183 - val_loss: 0.1072 - val_mae: 0.2657 - val_root_mean_squared_error: 0.3274
# Epoch 490/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1030 - mae: 0.2594 - root_mean_squared_error: 0.3209 - val_loss: 0.1072 - val_mae: 0.2656 - val_root_mean_squared_error: 0.3274
# Epoch 491/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1017 - mae: 0.2574 - root_mean_squared_error: 0.3188 - val_loss: 0.1072 - val_mae: 0.2656 - val_root_mean_squared_error: 0.3274
# Epoch 492/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1040 - mae: 0.2608 - root_mean_squared_error: 0.3225 - val_loss: 0.1072 - val_mae: 0.2656 - val_root_mean_squared_error: 0.3274
# Epoch 493/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1025 - mae: 0.2587 - root_mean_squared_error: 0.3201 - val_loss: 0.1072 - val_mae: 0.2656 - val_root_mean_squared_error: 0.3274
# Epoch 494/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - mae: 0.2621 - root_mean_squared_error: 0.3227 - val_loss: 0.1072 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3274
# Epoch 495/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1022 - mae: 0.2592 - root_mean_squared_error: 0.3197 - val_loss: 0.1071 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3273
# Epoch 496/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1046 - mae: 0.2616 - root_mean_squared_error: 0.3234 - val_loss: 0.1072 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3274
# Epoch 497/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1018 - mae: 0.2573 - root_mean_squared_error: 0.3191 - val_loss: 0.1071 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3273
# Epoch 498/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1022 - mae: 0.2589 - root_mean_squared_error: 0.3196 - val_loss: 0.1071 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3273
# Epoch 499/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1032 - mae: 0.2598 - root_mean_squared_error: 0.3213 - val_loss: 0.1072 - val_mae: 0.2655 - val_root_mean_squared_error: 0.3274
# Epoch 500/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1059 - mae: 0.2636 - root_mean_squared_error: 0.3254 - val_loss: 0.1072 - val_mae: 0.2654 - val_root_mean_squared_error: 0.3274

# %% [markdown]
# plot history:

# %%
# extract the history dictionary from the keras callback:
history_data = history.history

# drop the r2 scores from the history, getting a dictionary of just loss:
history_data.pop('r2_score', None)
history_data.pop('val_r2_score', None)

# list of metrics, text conversion, & halfway point:
metric_list = list(history_data.keys())
half = int(len(history_data.keys())/2)
metric2text = {'loss' : 'Loss',
               'mae' : 'Mean Absolute Error',
               'root_mean_squared_error': 'Root Mean Squared Error'
               }

# training history analysis:
plt.figure(figsize = (half * 5,5))

# iterate and plot the training values:
for index, metric in enumerate(metric_list[:half]):
    training_metric = metric
    validation_metric = metric_list[index + half]

    plt.subplot(1, half, index + 1)
    plt.plot(history_data[training_metric], label = training_metric)
    plt.plot(history_data[validation_metric], label = validation_metric)
    plt.xlabel('epoch')
    plt.legend(loc = 'upper right')
    plt.minorticks_on()
    plt.grid(which = 'major', color = 'black', linestyle = '--', linewidth = 0.5)
    plt.grid(which = 'minor', color = 'gray', linestyle = ':', linewidth = 0.5)
    plt.title(f'{metric2text[training_metric]}')

# %% [markdown]
# test this shit:

# %%
# need to get the test metrics through model evaluation:
test_loss, test_mae, test_rmse = model.evaluate(x_test, y_test)

# need to get the predictions of the model:
pred_start = time.time()
y_pred = model.predict(x_test)
pred_time = time.time() - pred_start

# get the R2 score:
test_r2 = r2_score(y_test, y_pred)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.1019 - mae: 0.2542 - root_mean_squared_error: 0.3191
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step

# %% [markdown]
# results:

# %%
# print model parameters to user:
print(f'test MSE was: {test_loss}\n',
      f'test MAE was: {test_mae}\n', 
      f'test RMSE was: {test_rmse}\n',
      f'test r2 score was: {test_r2}\n',
      f'prediction time was: {round(pred_time, 3)} seconds')
# Out:
# test MSE was: 0.10258616507053375
#  test MAE was: 0.25498512387275696
#  test RMSE was: 0.320290744304657
#  test r2 score was: 0.9571425914764404
#  prediction time was: 0.983 seconds

# %% [markdown]
# visualize through scatter plot:

# %%
# scatter plot analysis:
plt.figure()
plt.scatter(y_test, y_pred, s = 2)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color = 'red', lw = 2)

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted')

plt.grid(which = 'major', color = 'black', linestyle = '--', linewidth = 0.5)
plt.grid(which = 'minor', color = 'gray', linestyle = ':', linewidth = 0.5)
plt.minorticks_on()

# %% [markdown]
# histogram of errors:

# %%
# histogram analysis:
y_test = np.array(y_test).reshape(-1, 1)
error = y_test - y_pred

plt.figure()
plt.hist(error, bins = 100, edgecolor = 'black', linewidth = 0.25)

plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Histogram of Prediction Errors')

plt.show()

# %% [markdown]
# check mfs:

# %%
model.layers[1].plot_membership([10, 25, 50])
